# %% [markdown]
# probability of an event = number of favorable outcomes/ number of total possbile outcomes
#
# - what is the probability of
#     - getting a king of heart from a deck, in a single draw.
#
#     - there are 52 cards
#     -
#     - getting a queen from a deck, in a single draw -

# %% [markdown]
# Probability Distributions
#
# - frequency distributions???
#
# - if you have  dice, what are the values that the variable will take?
#
# - **face 2** can come up 10 times, or 9 or 8 times, within 10 throws
#
# - height or mark
#      - possible range of values - continous values

# %% [markdown]
# Binomial Distribution
#
# - flip a coin 100 times
# - success, HEADs -
# - H T
#
# - success - how many times to - 1/2
# - range - 0 to 100

# %% [markdown]
# --------
#
# - we flip 3 times
#
# - sequences of result:
# -

# %% [markdown]
# - Try and simulate binomial distribution, using python
#
# - three coin flips,
# -
#
# - Binomal - Discreate -
#
# - normal - continous -
#
#
# - 1000 students
# - mean marks
# - std_marks

# %%
import numpy as np

# %%
marks = np.random.normal(loc=85, scale= 30, size= 1000)

marks.mean()
marks.std()
# Out:
# np.float64(30.994793814384042)

# %%
import seaborn as sns

sns.histplot(marks, kde= True)
# Out:
# <Axes: ylabel='Count'>

# %%
# number of throws = 3
# p for each event = 0.5
# many times you want to repeat the experiment = 1000

throwoutcomes = np.random.binomial(n = 10, p = 0.5, size= 1000)

values = np.unique(throwoutcomes)
values

throwoutcomes
# Out:
# array([ 7,  3,  6,  5,  5,  4,  7,  4,  5,  6,  5,  5,  4,  7,  5,  4,  5,
#         5,  2,  3,  4,  8,  6,  6,  5,  5,  5,  4,  5,  4,  8,  6,  1,  3,
#         5,  3,  6,  6,  7,  6,  6,  3,  8,  2,  4,  4,  4,  4,  5,  6,  3,
#         3,  4,  4,  4,  3,  9,  4,  9,  6,  5,  4,  4,  4,  3,  8,  6,  6,
#         5,  9,  5,  6,  5,  3,  6,  4,  6,  6,  7,  4,  4,  5,  8,  5,  9,
#         7,  6,  6,  6,  4,  5,  5,  5,  5,  6,  7,  5,  3,  3,  7,  3,  6,
#         5,  4,  4,  6,  7,  4,  7,  3,  3,  7,  5,  4,  4,  7,  5,  3,  3,
#         6,  7,  4,  6,  7,  6,  7,  5,  6,  3,  5,  4,  5,  7,  6,  5,  6,
#         5,  4,  4,  2,  5,  5,  7,  7,  3,  4,  4,  7,  4,  6,  3,  6,  5,
#         5,  4,  7,  6,  4,  8,  6,  6,  6,  6,  6,  6,  6,  2,  7,  5,  5,
#         3,  3,  4,  7,  7,  8,  6,  7,  4,  6,  4,  3,  4,  5,  4,  5,  7,
#         4,  5,  6,  5,  5,  6,  4,  6,  8,  7,  6,  5,  6,  4,  4,  6,  4,
# ...

# %%
# single throw - 
# 0 - 
# 1 - 
# 2 - 

import pandas as pd

df = pd.DataFrame(throwoutcomes)

# %%
sns.histplot(df,kde=True)
# Out:
# <Axes: ylabel='Count'>
